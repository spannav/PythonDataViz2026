# %% [markdown]
# <a href="https://colab.research.google.com/github/spannav/PythonDataViz2026/blob/main/HW7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ศุภณัฏฐ์ ปุณมา

# %% [markdown]
# ## HW7 สร้างตารางใหม่ ที่ค่าใน ```sex``` เป็น missing ทั้งหมด
# - สรุปว่าทำไม record นั้นๆถึงเป็น missing

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/P3 T1/Aj.Ton/DATA/confirmed-cases-since-120864.csv'

# %%
fd = pd.read_csv(path)

# %%
sex_missing = fd[fd['sex'].isna()]

# %%
sex_missing.head()
# Out:
#         No. announce_date Notified date  sex   age Unit nationality  \
# 169  817159     12/8/2021     11/8/2021  NaN   NaN  NaN    Thailand
# 172  817162     12/8/2021     11/8/2021  NaN  41.0   ปี    Thailand
# 173  817163     12/8/2021     11/8/2021  NaN   NaN  NaN    Thailand
# 174  817164     12/8/2021     11/8/2021  NaN   NaN  NaN    Thailand
# 175  817165     12/8/2021     11/8/2021  NaN   NaN  NaN    Thailand
#
#     province_of_isolation                                         risk  \
# 169                  แพร่                                        อื่นๆ
# 172                  แพร่  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 173                  แพร่                                        อื่นๆ
# 174                  แพร่                                        อื่นๆ
# 175                  แพร่                                        อื่นๆ
#
#     province_of_onset district_of_onset
# 169               NaN               NaN
# 172               NaN               NaN
# ...
